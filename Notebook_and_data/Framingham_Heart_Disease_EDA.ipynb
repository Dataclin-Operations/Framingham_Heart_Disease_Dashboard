# %% [markdown]
# <img src="https://scontent.fcai20-6.fna.fbcdn.net/v/t1.18169-9/197432_241303492662381_1021137860_n.jpg?_nc_cat=103&ccb=1-7&_nc_sid=2a1932&_nc_ohc=G2XfNit9W68Q7kNvgFnM7c3&_nc_ht=scontent.fcai20-6.fna&oh=00_AYBo89wp0PctC3zQGiJeo9_wIiyuOi7zLuGbLt7eUbQmpw&oe=66A78E3E">

# %% [markdown]
# <a id='TOC'></a>
# </div>
#
# <div style=" border: 3px solid #13B3E7; border-radius:10px; font-size:115%;">
#
#
# <h2 style="padding-left:15px">Table of Contents</h2>
# <ul>
#
#
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#intro"> A. Intoduction</a></li>
#         <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a> </a></ul>
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#Quest"> B. Questions</a></li>
#         <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a> </a></ul>
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#wrangling"> C. Data Wrangling</a>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a> </a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a href="#Gathering">C.1. Data Gathering</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a href="#Assessing">C.2.  Data Assessing</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a href="#Cleaning">C.3  Data Cleaning</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a> </a></ul>
#     </li>
#
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#eda">D. Exploratory Data Analysis</a></li>
#          <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a> </a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a href="#Gathering">D.1. Data Gathering</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a href="#Assessing">D.2.  Data Assessing</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a href="#Cleaning">D.3.  Data Cleaning</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a> </a></ul>
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#        <a href="#FE">Feature Engineering</a>
#      <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>A. Add New Features</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>B. Drop Rows with missing vales</a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>C. Categorical Variables Encoding</ul>
#         <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>D. Featuer Importance</ul>
#     </li>
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#Modeling">Modeling</a>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>A. </a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>A. </a></ul>
#     <ul style="font: 12pt 'Candara'; margin-bottom: 6px;;">
#         <a>D. </a></ul>
#     </li>
#
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#conclusions">5. Conclusions</a></li>
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#recommendations">6. Recommendations</a></li>
# <li
#     style="font: 12pt 'Candara'; margin-bottom: 6px;font-weight:bold;">
#         <a href="#Limit">7. Limitations</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## A. Introduction
#
#
#
#
# > **Descriptions:**  The "Framingham" heart disease dataset includes over 4,240 records,16 columns and 15 attributes. The goal of the dataset is to predict whether the patient has 10-year risk of future (CHD) coronary heart disease:**
#
#
#
# **columns descriptions:**
#
# - **male:** Patient Gender Binary (1 = Male, 0 = Female)
# - **age:** Patient age.
# - **education:** Patient education level.
# - **currentSmok:** Smoker or not Binary (1 = Yes, 0 = No).
# - **cigsPerDay:** Number of smoking sigars per day
# - **BPMeds:** Blood Pressure Medications.
# - **prevalentStroke:** whether the individual has had a stroke previously Binary (1 = Yes, 0 = No).
# - **prevalentHyp:** whether the individual has prevalent hypertension (high blood pressure) Binary (1 = Yes, 0 = No).
# - **diabetes:** whether the individual has diabetes.  Binary (1 = Yes, 0 = No).
# - **totChol:** `Total Cholesterol` The total cholesterol level in the blood
# - **sysBP:** `Systolic Blood Pressure` The pressure in the arteries when the heart beats
# - **diaBP:** `Diastolic Blood Pressure` he pressure in the arteries when the heart is at rest between beats.
# - **BMI:** `Body Mass Index` A measure of body fat based on height and weight, calculated as weight (kg) / height (m)^2.
# - **heartRate:** Heartbeats per minute.
# - **glucose:** The blood glucose level
# - **TenYearCHD:** `Ten-Year Coronary Heart Disease Risk` The estimated risk of developing CHD over the next ten years

# %% [markdown]
# <a id='Quest'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ## **B. Questions:**
#
#
# **<a href ='#q1'> 1. What proportion of patients exhibits a ten-year risk of coronary heart disease (TenYearCHD)?</a>**
# > Reason: Understanding the distribution of the target variable helps to know if the dataset is imbalanced.
#
#
#
# **<a href ='#q2'> 2. Is there a statistically significant difference in 10-year CHD risk percentage between smokers and non-smokers, stratified by</a>**
#
# > * **Diabetes status**
#
# > * **Prevalent Stroke**
#
# > * **Blood Pressure Medications**
#
#
# **<a href ='#q3'>3.  Is there a statistically significant difference in 10-year CHD risk between Genders, stratified by: </a>**
#
# > * **Diabetes status**
#
# > * **Prevalent Stroke**
#
# > * **Blood Pressure Medications**
#
#
# **<a href ='#q4'> 4. Is there a statistically significant difference in 10-year CHD risk between Age groups, stratified by Diabetes status?</a>**
#
# **<a href ='#q5'> 5. Is there a statistically significant difference in 10-year CHD risk between BMI Category, stratified by Diabetes status?</a>**
#
#
# **<a href ='#q6'>6.  Is there a correlation between 10-year CHD risk and any of the following fratures: </a>**
#
# > * **Age**
#
# > * **Smoking patterns**
#
# > * **Blood Pressure**
#
# > * **BMI**
#
#
# **<a href ='#q7'> 7. What is the average number of cigarettes smoked per day for patients with and without 10-year CHD risk?</a>**

# %% [markdown]
# ### importing libraries that will be used to investigate Dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
import plotly.express as px
import plotly.graph_objects as go
import plotly.express as px
import datetime
sns.set_style("whitegrid")
pd.options.display.max_colwidth = 20
pd.options.display.max_columns = 50

# %% [markdown]
# <a id='wrangling'></a>
#
#
# ## C. Data Wrangling
#
#  **This is a three step process:**
#
# *  Gathering the data from Dataset and investegate it trying to understand more details about it.
#
#
# *  Assessing data to identify any issues with data types, structure, or quality.
#
#
# *  Cleaning data by changing data types, replacing values, removing unnecessary data and modifying Dataset for easy and fast analysis.

# %% [markdown]
# <a id='Gathering'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
#
# ### C.1. Data Gathering

# %%
# load CSV files in to 3 Dataframes  //patients, treatments and adverse reaction//

df = pd.read_csv("framingham.csv")

# %%
#check 5 rows sample from Dataframes

df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# <a id='Assessing'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
#
# ### C.2. Data Assessing

# %%
#check Dataframe basic informations (columns names, number of values, data types ......)


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
#check Dataframe shape (number of rows and columns)

df.shape
# Out:
# (4240, 16)

# %%
#check more information and descriptive statistics for Quantitative variables

df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
# check for NaN values patients

df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
#check for duplicated rows 

df.duplicated().sum()
# Out:
# 0

# %%
#check number of unique values

df.nunique()
# Out:
# male                  2
# age                  39
# education             4
# currentSmoker         2
# cigsPerDay           33
# BPMeds                2
# prevalentStroke       2
# prevalentHyp          2
# diabetes              2
# totChol             248
# sysBP               234
# diaBP               146
# BMI                1364
# heartRate            73
# glucose             143
# TenYearCHD            2
# dtype: int64

# %%
# Check value counts for all columns

print("-------------------------------------------")
for i in df.columns:
    print(df[i].value_counts(normalize=True,sort=True,))
    print("-------------------------------------------")
# Out:
# -------------------------------------------
# male
# 0    0.570755
# 1    0.429245
# Name: proportion, dtype: float64
# -------------------------------------------
# age
# 40    0.045283
# 46    0.042925
# 42    0.042453
# 41    0.041038
# 48    0.040802
# 39    0.040094
# 44    0.039151
# 45    0.038208
# 43    0.037500
# 52    0.035142
# 51    0.034434
# 55    0.034198
# 38    0.033962
# 47    0.033255
# 50    0.033019
# 53    0.032783
# 54    0.031132
# 49    0.031132
# 57    0.029009
# 56    0.029009
# 59    0.028066
# 58    0.027594
# 60    0.026179
# 63    0.025943
# 61    0.025943
# 62    0.023349
# 64    0.021934
# 37    0.021698
# 36    0.019811
# 65    0.013443
# 67    0.010613
# 35    0.009906
# 66    0.008962
# 34    0.004245
# 68    0.004245
# 69    0.001651
# 33    0.001179
# 70    0.000472
# 32    0.000236
# Name: proportion, dtype: float64
# -------------------------------------------
# education
# 1.0    0.415961
# 2.0    0.303023
# 3.0    0.166626
# 4.0    0.114389
# ...

# %% [markdown]
# <a id='Cleaning'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
#
# ### C.3. Data Cleaning

# %%
# function to clean data 
def wrangle(df):
    #Fill null values
    df.loc[:, 'education'] = df['education'].fillna(-1)
    df = df.dropna(subset=['cigsPerDay'])
    df.loc[:, 'BPMeds'] = df['BPMeds'].fillna(-1)
    # df["BPMeds"].fillna(-1, inplace=True)
    df = df.dropna(subset=['totChol'])
    df = df.dropna(subset=['heartRate'])
    df = df.dropna(subset=['glucose'])
    df = df.dropna(subset=['BMI'])

    # Fix Datatypes
    df["education"] = df["education"].astype(int)
    df["cigsPerDay"] = df["cigsPerDay"].astype(int)

    # Make age groupos 	
    age_bins = [30, 40, 50, 60, 70, np.inf]
    age_labels = ['Thirties', 'Forties', 'Fifties', 'Sixties', 'Seventies or Older']
    
    # Create a new column for age group with descriptive labels
    df['ageGroup'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)


    # Make BMI Groups 
    
    bmi_bins = [0, 18.6, 25, 30, np.inf]
    bmi_labels = ['Underweight', 'Normal weight', 'Overweight', 'Obesity']
    
    # Create BMI categories
    df['BMICategory'] = pd.cut(df['BMI'], bins=bmi_bins, labels=bmi_labels, right=False)

    # Add MAP column Mean Arterial Pressure MAP = (SBP + 2 (DBP))/3
    df['MAP'] = (df['sysBP'] + 2 * df['diaBP']) / 3

    return df

# %%
df_clean = wrangle(df)
df_clean.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39          4              0           0     0.0                0
# 1     0   46          2              0           0     0.0                0
# 2     1   48          1              1          20     0.0                0
# 3     0   61          3              1          30     0.0                0
# 4     0   46          3              1          23     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  ageGroup    BMICategory         MAP
# ...

# %%
## Make Charts Functions

def bar_chart(df, xx, yy,  txt="", labls={},hover={}, colors=[], height=600, width=900, ttle="ttle",xtitle="xtitle" , ytitle="ytitle" ,colour=None, bg=0.6, bgg=0.1, leg=None, box=False,yscale=False,yscale_percentage=False, start=-1, end=1):
    if box:
        fig = px.box(df,  x=xx, y=yy, color=colour,
            color_discrete_sequence=colors,height=600, width=1100
            )
    elif colour ==None:
        fig = px.bar(df, x=xx, y=yy, barmode='group',text=txt,
             labels=labls,
             hover_data=hover,
             title=ttle,
            color_discrete_sequence=colors,
                     height=600, width=900)
    else:
        fig = px.bar(df, x=xx, y=yy, color=colour, barmode='group',text=txt,
                     labels=labls,
                     hover_data=hover,
                     title=ttle,
                     color_discrete_sequence=colors,height=600, width=900)


    if box == False:
        fig.update_traces(textfont_size=15, textposition='outside')
    
    fig.update_layout(
        legend_title_text=leg,
        #background 
        plot_bgcolor="white",  #background color
        bargap=bg,  # Gap between bars
        bargroupgap=bgg, 
    
        # Title
         title={'text': ttle, 'y': 0.95, 'x': 0.5, 'xanchor': 'center', 'yanchor': 'top'}, #title center and size
         title_font_size=20,  # Title font size
    
        # Xaxis
        xaxis=dict(
            title=xtitle,  # Example X axis title
            titlefont_size=14,  # Size of the X axis title font
            tickfont_size=12,   # Size of the X axis tick labels font
            showline=True,  # Show x-axis line
            showgrid=False, # showgrid
            gridcolor="lightgray", #grid color
            
        ),
        yaxis=dict(
            title=ytitle,  # Example Y axis title
            titlefont_size=14,  # Size of the Y axis title font
            tickfont_size=12,   # Size of the Y axis tick labels font
         
            showgrid=True, # showgrid
            
        ),

    legend=dict(
                font_size=12,  # Size of the legend font
                
            ),
        # font
        font=dict(
            family='Arial', size=14  # Overall font size
        )
    )
    if yscale_percentage and yscale:
        fig.update_xaxes(title_text=xtitle, # Y axisTitle
                         zeroline=True,
                         showline=True,  # Show y-axis line
                        linecolor='gray',
                        titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)
                         )
        fig.update_yaxes(title_text=ytitle, # Y axisTitle
                         range=[start, end],
                         tickformat='.0%',
                         zeroline=True,
                         showline=True,  # Show y-axis line
                         linecolor='gray',  # Color of the y-axis line
                         titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)         )
                        )
    elif yscale_percentage:
        fig.update_xaxes(title_text=xtitle, # Y axisTitle
                         zeroline=True,
                         showline=True,  # Show y-axis line
                        linecolor='gray',
                        titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)
                         )
        fig.update_yaxes(title_text=ytitle, # Y axisTitle
                         zeroline=True,
                         tickformat='.0%',
                         showline=True,  # Show y-axis line
                         linecolor='gray',  # Color of the y-axis line
                         titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)         )
                        )
    elif yscale:
        fig.update_xaxes(title_text=xtitle, # Y axisTitle
                         zeroline=True,
                         showline=True,  # Show y-axis line
                        linecolor='gray',
                        titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)
                         )
        fig.update_yaxes(title_text=ytitle, # Y axisTitle
                         range=[start, end],
                         zeroline=True,
                         showline=True,  # Show y-axis line
                         linecolor='gray',  # Color of the y-axis line
                         titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)         )
                        )
    else:
        fig.update_xaxes(title_text=xtitle, # Y axisTitle
                         showline=True,  # Show y-axis line
                        linecolor='gray',
                        titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)
                         )
        
        fig.update_yaxes(title_text=ytitle, # Y axisTitle
                         showline=True,  # Show y-axis line
                         linecolor='gray',  # Color of the y-axis line
                         titlefont_size=14,  # Set the title font size (optional)
                        titlefont_color="black",  # Set the title font color (optional)         )
                        )
        # Show the plot
    fig.show()

# %% [markdown]
# <a id='eda'></a>
#
# ## D. Exploratory Data Analysis
#
# > Now I'm going to explore this data and try to find patterns in it, compute statistics and visualize the relationships
# to answer the questions and detect the characteristics that affect patients attending to their hospital appointment

# %% [markdown]
# <a id='q1'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 1
#
# > #### 1. What proportion of patients exhibits a ten-year risk of coronary heart disease (TenYearCHD)?

# %%
TenY_propotions = df_clean['TenYearCHD'].value_counts(normalize=True)
TenY_propotions = pd.DataFrame(TenY_propotions).reset_index()
TenY_propotions["TenYearCHD"] = TenY_propotions["TenYearCHD"].apply(lambda x: "CHD" if x ==1 else "No CHD")
TenY_propotions["proportion"] = round(TenY_propotions["proportion"]*100, 2)
TenY_propotions["countt"] = df_clean['TenYearCHD'].value_counts().values
TenY_propotions
# Out:
#   TenYearCHD  proportion  countt
# 0     No CHD       84.67    3219
# 1        CHD       15.33     583

# %%
import plotly.express as px
fig = px.pie(TenY_propotions, values='proportion', names="TenYearCHD",
             labels = {'proportion': 'Percentage' ,'countt':'Count'},
             custom_data=['countt'], 
             hover_data={'TenYearCHD': False,'countt':True},
             color_discrete_sequence=['#008294','#bdbdbd'],height=400)
fig.update_traces( # Change marker color
                  marker_line_color='black',  # Marker line color
                  marker_line_width=1,  # Marker line width
                  opacity=1,
                  hoverinfo='label+percent+value',  # Display label, percent, and value on hover
                  texttemplate='%{value:.2f}',
                  textinfo='percent', textfont_size=16)  # Display percent and label in each segment

fig.update_layout(
    title={'text': 'Proportion of Patients with Ten-Year CHD Risk', 'y': 0.95, 'x': 0.5, 'xanchor': 'center', 'yanchor': 'top'},  # Center and adjust title
    title_font_size=20,  # Title font size
    legend_title_text='Risk',  # Legend title
    font=dict(family='Arial', size=14),  # Font family and size for labels
)
fig.show()

# %% [markdown]
# ## Answer 1
#
#
#    - **From above visualisation we can see a class imbalance, with approximately 85% of patients classified as having no ten-year coronary heart disease (CHD) risk. The remaining 15% of patients exhibit an elevated risk of developing CHD within the next ten years.**

# %% [markdown]
# <a id='q2'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 2
#
# > #### 2. Is there a statistically significant difference in 10-year CHD risk percentage between smokers and non-smokers, stratified by:
#
# * **Diabetes status**
#
# * **Prevalent Stroke**
#
# * **Blood Pressure Medications**

# %% [markdown]
# ### A. Diabetes status

# %%
grouped_chd_dia = df_clean.groupby(['currentSmoker',"diabetes"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_dia["currentSmoker"] = grouped_chd_dia["currentSmoker"].apply(lambda x : "Smoker" if x == 1 else "Non-Smoker")
grouped_chd_dia["diabetes"] = grouped_chd_dia["diabetes"].apply(lambda x : "Diabetes" if x == 1 else "Non-Diabetes")
# k["per"] = round(k["per"]*100, 2)
grouped_chd_dia["annotation_per"] = round(grouped_chd_dia["per"]*100, 2)
grouped_chd_dia["annotation_per"] = grouped_chd_dia["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_dia
# Out:
#   currentSmoker      diabetes       per annotation_per
# 0    Non-Smoker  Non-Diabetes  0.138224        13.82 %
# 1    Non-Smoker      Diabetes  0.367647        36.76 %
# 2        Smoker  Non-Diabetes  0.157402        15.74 %
# 3        Smoker      Diabetes  0.333333        33.33 %

# %%
bar_chart(
    grouped_chd_dia,
    "currentSmoker",
    "per",
    txt = "annotation_per",
    labls = {'currentSmoker': 'Current Smoker', 'diabetes': 'Diabetes', 'per': 'CHD Risk', "annotation_per": "False"},
    hover={"annotation_per":False},
    colors =['#4D4D4D','#008294'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Smoking Status vs. Diabetes",
    xtitle="Smoking Status" ,
    ytitle="10-Year CHD Risk %" ,
    colour='diabetes', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# #### **From above visualisation we can see that**
#
# <h5>1. <b>Diabetic Patients:</b> Patients with diabetes, regardless of smoking status, exhibit a higher risk of CHD compared to those without diabetes. Specifically, non-smokers with diabetes have approximately a 37% risk, whereas smokers with diabetes have a 33% risk.</h5>
#
# <h5>2. <b>Non-Diabetic Patients:</b> Conversely, patients without diabetes have a significantly lower CHD risk. Here, non-smokers have a 14% risk, while smokers have a slightly higher risk of 16%.</h5>
#
# <h4><b>3.  The overall risk appears higher in Diabetic patients</b></h4>

# %% [markdown]
# ### B. Prevalent Stroke

# %%
grouped_chd_pstro = df_clean.groupby(['currentSmoker',"prevalentStroke"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_pstro["currentSmoker"] = grouped_chd_pstro["currentSmoker"].apply(lambda x : "Smoker" if x == 1 else "Non-Smoker")
grouped_chd_pstro["prevalentStroke"] = grouped_chd_pstro["prevalentStroke"].apply(lambda x : "Had Stroke" if x == 1 else "No-Stroke")
# k["per"] = round(k["per"]*100, 2)
grouped_chd_pstro["annotation_per"] = round(grouped_chd_pstro["per"]*100, 2)
grouped_chd_pstro["annotation_per"] = grouped_chd_pstro["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_pstro
# Out:
#   currentSmoker prevalentStroke       per annotation_per
# 0    Non-Smoker       No-Stroke  0.144410        14.44 %
# 1    Non-Smoker      Had Stroke  0.352941        35.29 %
# 2        Smoker       No-Stroke  0.159632        15.96 %
# 3        Smoker      Had Stroke  0.600000         60.0 %

# %%
bar_chart(
    grouped_chd_pstro,
    "currentSmoker",
    "per",
    txt = "annotation_per",
    labls = {'currentSmoker': 'Current Smoker', 'prevalentStroke': 'Prevalent Stroke', 'per': 'CHD Risk', "annotation_per": "False"},
    hover={"annotation_per":False},
    colors =['#8A8D90','#1192e9'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Smoking Status vs. Prevalent Stroke",
    xtitle="Smoking Status" ,
    ytitle="10-Year CHD Risk %" ,
    colour='prevalentStroke', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# #### **From above visualisation we can see that**
#
# <h5>1. <b>Patients with a History of Stroke:</b> Smokers with a history of stroke have a notably higher 10-year CHD risk (approximately 60%) compared to non-smokers with a history of stroke (approximately 35.29%). This highlights the substantial risk amplification associated with smoking in this population..</h5>
#
# <h5>2. <b>Patients without a History of Stroke:</b>For those who haven't experienced a prior stroke, the 10-year CHD risk appears less dependent on smoking status. Smokers in this group have a risk of around 16%, while non-smokers have a slightly lower risk of 14%..</h5>
#
# <h4><b>3.  The overall risk appears higher in patients with a History of Stroke</b></h4>

# %% [markdown]
# ### C. Blood Pressure Medications

# %%
grouped_chd_bp = df_clean.groupby(['currentSmoker',"BPMeds"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_bp["currentSmoker"] = grouped_chd_bp["currentSmoker"].apply(lambda x : "Smoker" if x == 1 else "Non-Smoker")
grouped_chd_bp["BPMeds"] = grouped_chd_bp["BPMeds"].astype(int)
grouped_chd_bp["BPMeds"] = grouped_chd_bp["BPMeds"].astype(str)
dic5 = {
    "0": "No Meds",
    "1": "Med Users",
    "-1": "NA",
       }
grouped_chd_bp["BPMeds"] = grouped_chd_bp["BPMeds"].map(dic5)
# k["per"] = round(k["per"]*100, 2)
grouped_chd_bp["annotation_per"] = round(grouped_chd_bp["per"]*100, 2)
grouped_chd_bp["annotation_per"] = grouped_chd_bp["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_bp
# Out:
#   currentSmoker     BPMeds       per annotation_per
# 0    Non-Smoker         NA  0.233333        23.33 %
# 1    Non-Smoker    No Meds  0.136659        13.67 %
# 2    Non-Smoker  Med Users  0.346667        34.67 %
# 3        Smoker         NA  0.190476        19.05 %
# 4        Smoker    No Meds  0.157836        15.78 %
# 5        Smoker  Med Users  0.282051        28.21 %

# %%
bar_chart(
    grouped_chd_bp,
    "currentSmoker",
    "per",
    txt = "annotation_per",
    labls = {'currentSmoker': 'Current Smoker', 'BPMeds': 'Blood Presure Medication', 'per': 'CHD Risk', "annotation_per": "False"},
    hover={"annotation_per":False},
    colors =["#1e3d59",'silver','#FF7F0E',] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Smoking Status vs. Blood Presure Medication",
    xtitle="Smoking Status" ,
    ytitle="10-Year CHD Risk %" ,
    colour='BPMeds', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True,
    leg="Blood Presure Medication"
)

# %% [markdown]
# #### **From above visualisation we can see that**
#
# <h5>1. <b>Patients on BP Medications:</b> Surprisingly, non-smokers using BP medications exhibit a higher 10-year CHD risk (approximately 35%) compared to smokers on BP medications (approximately 28%).</h5>
#
# <h5>2. <b>Patients Not on BP Medications:</b>Conversely, for those not using BP medications, the risk pattern is more typical. Smokers in this group have a sligtly higher CHD risk (approximately 16%) compared to non-smokers (approximately 14%).</h5>
#
# <h4><b>3.  The overall risk appears higher in patients on on BP Medications</b></h4>

# %% [markdown]
# ### D. Prevalen Hypertension

# %%
grouped_chd_hyper_smoke = df_clean.groupby(['currentSmoker',"prevalentHyp"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_hyper_smoke["currentSmoker"] = grouped_chd_hyper_smoke["currentSmoker"].apply(lambda x : "Smoker" if x == 1 else "Non-Smoker")
grouped_chd_hyper_smoke["prevalentHyp"] = grouped_chd_hyper_smoke["prevalentHyp"].apply(lambda x : "Had Hypertension" if x == 1 else "No-Hypertension")

grouped_chd_hyper_smoke["annotation_per"] = round(grouped_chd_hyper_smoke["per"]*100, 2)
grouped_chd_hyper_smoke["annotation_per"] = grouped_chd_hyper_smoke["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_hyper_smoke
# Out:
#   currentSmoker      prevalentHyp       per annotation_per
# 0    Non-Smoker   No-Hypertension  0.090909         9.09 %
# 1    Non-Smoker  Had Hypertension  0.243626        24.36 %
# 2        Smoker   No-Hypertension  0.126554        12.66 %
# 3        Smoker  Had Hypertension  0.257202        25.72 %

# %%
bar_chart(
    grouped_chd_hyper_smoke,
    "currentSmoker",
    "per",
    txt = "annotation_per",
    labls = {'currentSmoker': 'Current Smoker', 'prevalentHyp': 'Prevalent Hypertension', 'per': 'CHD Risk', "annotation_per": "False"},
    hover={"annotation_per":False},
    colors =['#7a2048','#408ec6'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Smoking Status vs. Prevalent Hypertension",
    xtitle="Smoking Status" ,
    ytitle="10-Year CHD Risk %" ,
    colour='prevalentHyp', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# ## Answer 2
#
#
# ### From above visualization we can see:
#
# 1. **Diabetic Patients:** Patients with diabetes, regardless of smoking status, exhibit a higher risk of CHD compared to those without diabetes. Specifically, non-smokers with diabetes have approximately a 37% risk, whereas smokers with diabetes have a 33% risk.
# 2. **Non-Diabetic Patients:** Conversely, patients without diabetes have a significantly lower CHD risk. Here, non-smokers have a 14% risk, while smokers have a slightly higher risk of 16%.
# 3. **The overall risk appears higher in Diabetic patients**
# 4. **Patients with a History of Stroke:** Smokers with a history of stroke have a notably higher 10-year CHD risk (approximately 60%) compared to non-smokers with a history of stroke (approximately 35.29%). This highlights the substantial risk amplification associated with smoking in this population
# 5.  **Patients without a History of Stroke:** For those who haven't experienced a prior stroke, the 10-year CHD risk appears less dependent on smoking status. Smokers in this group have a risk of around 16%, while non-smokers have a slightly lower risk of 14%.
# 6.  **The overall risk appears higher in patients with a History of Stroke.**
# 7.  **Patients on BP Medications:** Surprisingly, non-smokers using BP medications exhibit a higher 10-year CHD risk (approximately 35%) compared to smokers on BP medications (approximately 28%).
# 8. **Patients Not on BP Medications:** Conversely, for those not using BP medications, the risk pattern is more typical. Smokers in this group have a sligtly higher CHD risk (approximately 16%) compared to non-smokers (approximately 14%).
# 9. **The overall risk appears higher in patients on on BP Medications.**

# %% [markdown]
# <a id='q3'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 3
#
# > #### 3. Is there a statistically significant difference in 10-year CHD risk between Genders, stratified by:
#
# * **Diabetes status**
#
# * **Prevalent Stroke**
#
# * **Blood Pressure Medications**

# %% [markdown]
# ### A. Diabetes status

# %%
grouped_chd_gender = df_clean.groupby(['male',"diabetes"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_gender["male"] = grouped_chd_gender["male"].apply(lambda x : "Male" if x == 1 else "Female")
grouped_chd_gender["diabetes"] = grouped_chd_gender["diabetes"].apply(lambda x : "Diabetes" if x == 1 else "Non-Diabetes")

grouped_chd_gender["annotation_per"] = round(grouped_chd_gender["per"]*100, 2)
grouped_chd_gender["annotation_per"] = grouped_chd_gender["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_gender
# Out:
#      male      diabetes       per annotation_per
# 0  Female  Non-Diabetes  0.119244        11.92 %
# 1  Female      Diabetes  0.296296        29.63 %
# 2    Male  Non-Diabetes  0.183486        18.35 %
# 3    Male      Diabetes  0.420000         42.0 %

# %%
bar_chart(
    grouped_chd_gender,
    "male",
    "per",
    txt = "annotation_per",
    labls = {'male': 'Gender', 'diabetes': 'Diabetes', 'per': 'CHD Risk'},
    hover={"annotation_per":False},
    colors =['#4D4D4D','#008294'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Gender vs. Diabetes",
    xtitle="Gender" ,
    ytitle="10-Year CHD Risk %" ,
    colour='diabetes', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# #### **From above visualisation we can see that**
#
# <h5>1. <b>Diabetic Patients:</b> Males with diabetes exhibit a notably higher 10-year CHD risk (approximately 42%) compared to Females with diabetes (approximately 30%). This highlights the substantial risk for Diabetic patients increase associated with Males.</h5>
#
# <h5>2. <b>Non-Diabetic Patients:</b>A similar pattern is observed in Non-Diabetic patients, Non-diabetes Males have a higher risk (approximately 18%) compared to Females without diabetes (approximately 12%).</h5>
#
# <h4><b>3.  The overall risk appears lower in females compared to males for both diabetic and non-diabetic groups.</b></h4>

# %% [markdown]
# ### B. Prevalent Stroke

# %%
grouped_chd_pstro = df_clean.groupby(['male',"prevalentStroke"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_pstro["male"] = grouped_chd_pstro["male"].apply(lambda x : "Male" if x == 1 else "Female")
grouped_chd_pstro["prevalentStroke"] = grouped_chd_pstro["prevalentStroke"].apply(lambda x : "Had Stroke" if x == 1 else "No-Stroke")

grouped_chd_pstro["annotation_per"] = round(grouped_chd_pstro["per"]*100, 2)
grouped_chd_pstro["annotation_per"] = grouped_chd_pstro["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_pstro
# Out:
#      male prevalentStroke       per annotation_per
# 0  Female       No-Stroke  0.122148        12.21 %
# 1  Female      Had Stroke  0.384615        38.46 %
# 2    Male       No-Stroke  0.189141        18.91 %
# 3    Male      Had Stroke  0.444444        44.44 %

# %%
bar_chart(
    grouped_chd_pstro,
    "male",
    "per",
    txt = "annotation_per",
    labls = {'male': 'Gender', 'prevalentStroke': 'Prevalent Stroke', 'per': 'CHD Risk', "annotation_per": "False"},
    hover={"annotation_per":False},
    colors =['#8A8D90','#1192e9'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Gender vs. Prevalent Stroke",
    xtitle="Gender" ,
    ytitle="10-Year CHD Risk %" ,
    colour='prevalentStroke', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# #### **From above visualisation we can see that**
#
# <h5>1. <b>Patients with a History of Stroke:</b> Males with a History of Stroke exhibit a notably higher 10-year CHD risk (approximately 44%) compared to Females with a History of Stroke (approximately 38%). This highlights the substantial risk for patients with a History of Stroke increase associated with Males.</h5>
#
# <h5>2. <b>Patients without a History of Stroke:</b>A similar pattern is observed in Males without a History of Stroke exhibit, higher 10-year CHD risk (approximately 19%) compared to Females with a History of Stroke (approximately 12%).</h5>
#
# <h4><b>3.  The overall risk appears lower in females compared to males for both patients with and without History of Stroke.</b></h4>

# %% [markdown]
# ### C. Blood Pressure Medications

# %%
grouped_chd_med = df_clean.groupby(['male',"BPMeds"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_med["male"] = grouped_chd_med["male"].apply(lambda x : "Male" if x == 1 else "Female")
grouped_chd_med["BPMeds"] = grouped_chd_med["BPMeds"].astype(int)
grouped_chd_med["BPMeds"] = grouped_chd_med["BPMeds"].astype(str)
dic5 = {
    "0": "No Meds",
    "1": "Med Users",
    "-1": "NA",
       }
grouped_chd_med["BPMeds"] = grouped_chd_med["BPMeds"].map(dic5)
# k["per"] = round(k["per"]*100, 2)
grouped_chd_med["annotation_per"] = round(grouped_chd_med["per"]*100, 2)
grouped_chd_med["annotation_per"] = grouped_chd_med["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_med
# Out:
#      male     BPMeds       per annotation_per
# 0  Female         NA  0.250000         25.0 %
# 1  Female    No Meds  0.114443        11.44 %
# 2  Female  Med Users  0.300000         30.0 %
# 3    Male         NA  0.133333        13.33 %
# 4    Male    No Meds  0.187042         18.7 %
# 5    Male  Med Users  0.382353        38.24 %

# %%
bar_chart(
    grouped_chd_med,
    "male",
    "per",
    txt = "annotation_per",
    labls = {'male': 'Gender', 'BPMeds': 'Blood Presure Medication', 'per': 'CHD Risk', "annotation_per": False},
    hover={"annotation_per":False},
    colors =["#1e3d59",'silver','#FF7F0E',] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Gender vs. Blood Presure Medication",
    xtitle="Gender" ,
    ytitle="10-Year CHD Risk %" ,
    colour='BPMeds', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True,
    leg="Blood Presure Medication"
)

# %% [markdown]
# #### **From above visualisation we can see that**
#
# <h5>1. <b>Patients on BP Medications:</b> Males on BP medications exhibit a higher 10-year CHD risk (approximately 38%) compared to Females on BP medications (approximately 30%).</h5>
#
# <h5>2. <b>Patients Not on BP Medications:</b> A similar pattern is observed Males who not on BP medications, have higher CHD risk (approximately 19%) compared to females who not on BP medications (approximately 11%).</h5>
#
# <h4><b>3.  The overall risk appears higher in Males patients and on patients on BP Medications</b></h4>

# %%
df_clean
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39          4              0           0     0.0
# 1        0   46          2              0           0     0.0
# 2        1   48          1              1          20     0.0
# 3        0   61          3              1          30     0.0
# 4        0   46          3              1          23     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4234     1   51          3              1          43     0.0
# 4235     0   48          2              1          20    -1.0
# 4237     0   52          2              0           0     0.0
# 4238     1   40          3              0           0     0.0
# 4239     0   39          3              1          30     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
grouped_chd_hyper = df_clean.groupby(['male',"prevalentHyp"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_hyper["male"] = grouped_chd_hyper["male"].apply(lambda x : "Male" if x == 1 else "Female")
grouped_chd_hyper["prevalentHyp"] = grouped_chd_hyper["prevalentHyp"].apply(lambda x : "Had Hypertension" if x == 1 else "No-Hypertension")

grouped_chd_hyper["annotation_per"] = round(grouped_chd_hyper["per"]*100, 2)
grouped_chd_hyper["annotation_per"] = grouped_chd_hyper["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_hyper
# Out:
#      male      prevalentHyp       per annotation_per
# 0  Female   No-Hypertension  0.076289         7.63 %
# 1  Female  Had Hypertension  0.228097        22.81 %
# 2    Male   No-Hypertension  0.151515        15.15 %
# 3    Male  Had Hypertension  0.275472        27.55 %

# %%
bar_chart(
    grouped_chd_hyper,
    "male",
    "per",
    txt = "annotation_per",
    labls = {'male': 'Gender', 'prevalentHyp': 'Prevalent Hypertension', 'per': 'CHD Risk', "annotation_per": "False"},
    hover={"annotation_per":False},
    colors =['#7a2048','#408ec6'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Gender vs. Prevalent Hypertension",
    xtitle="Gender" ,
    ytitle="10-Year CHD Risk %" ,
    colour='prevalentHyp', 
    bg=0.6, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True,
    leg="prevalentHyp"
)

# %% [markdown]
# ## Answer 3
#
#
# ### From above visualization we can see:
#
# 1. **Diabetic Patients:** Males with diabetes exhibit a notably higher 10-year CHD risk (approximately 42%) compared to Females with diabetes (approximately 30%). This highlights the substantial risk for Diabetic patients increase associated with Males.
# 2. **Non-Diabetic Patients:** A similar pattern is observed in Non-Diabetic patients, Non-diabetes Males have a higher risk (approximately 18%) compared to Females without diabetes (approximately 12%).
# 3. **The overall risk appears lower in females compared to males for both diabetic and non-diabetic groups.**
# 4. **Patients with a History of Stroke:** Males with a History of Stroke exhibit a notably higher 10-year CHD risk (approximately 44%) compared to Females with a History of Stroke (approximately 38%). This highlights the substantial risk for patients with a History of Stroke increase associated with Males.
# 5.  **Patients without a History of Stroke:** A similar pattern is observed in Males without a History of Stroke exhibit, higher 10-year CHD risk (approximately 19%) compared to Females with a History of Stroke (approximately 12%)
# 6.  **The overall risk appears lower in females compared to males for both patients with and without History of Stroke.**
# 7.  **Patients on BP Medications:** SMales on BP medications exhibit a higher 10-year CHD risk (approximately 38%) compared to Females on BP medications (approximately 30%).
# 8. **Patients Not on BP Medications:** A similar pattern is observed Males who not on BP medications, have higher CHD risk (approximately 19%) compared to females who not on BP medications (approximately 11%).
# 9. **The overall risk appears higher in Males patients and on patients on BP Medications.**

# %% [markdown]
# <a id='q4'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 4
#
# > #### 4. Is there a statistically significant difference in 10-year CHD risk between Age groups, stratified by Diabetes status?

# %%
grouped_chd_age = df_clean.groupby(['ageGroup',"diabetes"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_age["diabetes"] = grouped_chd_age["diabetes"].apply(lambda x : "Diabetes" if x == 1 else "Non-Diabetes")

grouped_chd_age["annotation_per"] = round(grouped_chd_age["per"]*100, 2)
grouped_chd_age["annotation_per"] = grouped_chd_age["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_age.dropna(inplace=True)
grouped_chd_age
# Out:
#              ageGroup      diabetes       per annotation_per
# 0            Thirties  Non-Diabetes  0.044625         4.46 %
# 1            Thirties      Diabetes  0.000000          0.0 %
# 2             Forties  Non-Diabetes  0.093579         9.36 %
# 3             Forties      Diabetes  0.272727        27.27 %
# 4             Fifties  Non-Diabetes  0.193211        19.32 %
# 5             Fifties      Diabetes  0.441860        44.19 %
# 6             Sixties  Non-Diabetes  0.279188        27.92 %
# 7             Sixties      Diabetes  0.333333        33.33 %
# 8  Seventies or Older  Non-Diabetes  0.000000          0.0 %

# %%
bar_chart(
    grouped_chd_age,
    "ageGroup",
    "per",
    txt = "annotation_per",
    labls = {'ageGroup': 'Age Group', 'diabetes': 'Diabetes', 'per': 'CHD Risk'},
    hover={"annotation_per":False},
    colors =['#bdbdbd','#008294'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: Age Group vs. Diabetes",
    xtitle="Age Group" ,
    ytitle="10-Year CHD Risk %" ,
    colour='diabetes', 
    bg=0.3, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# ## Answer 4
#
#
# ### From above visualizations we can see:
#
# **1. Across the forties, fifties, and sixties age groups, individuals with diabetes consistently exhibit a higher 10-year CHD risk compared to their non-diabetic counterparts.**
#
# **2. Among diabetic patients, the highest CHD risk is observed in the fifties (44%), followed by a slight decrease in the sixties (33%).**
#
# **3. For non-diabetic patients, the CHD risk progressively increases with age, reaching its peak in the sixties (28%**

# %% [markdown]
# <a id='q5'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 5
#
# > #### 5. Is there a statistically significant difference in 10-year CHD risk between BMI Category, stratified by Diabetes status?

# %%
grouped_chd_bmi = df_clean.groupby(['BMICategory',"diabetes"]).TenYearCHD.mean().reset_index(name='per')
grouped_chd_bmi["diabetes"] = grouped_chd_bmi["diabetes"].apply(lambda x : "Diabetes" if x == 1 else "Non-Diabetes")

grouped_chd_bmi["annotation_per"] = round(grouped_chd_bmi["per"]*100, 2)
grouped_chd_bmi["annotation_per"] = grouped_chd_bmi["annotation_per"].apply(lambda x : str(x) + " %")
grouped_chd_bmi
# Out:
#      BMICategory      diabetes       per annotation_per
# 0    Underweight  Non-Diabetes  0.142857        14.29 %
# 1    Underweight      Diabetes  0.500000         50.0 %
# 2  Normal weight  Non-Diabetes  0.118253        11.83 %
# 3  Normal weight      Diabetes  0.269231        26.92 %
# 4     Overweight  Non-Diabetes  0.167424        16.74 %
# 5     Overweight      Diabetes  0.382979         38.3 %
# 6        Obesity  Non-Diabetes  0.188053        18.81 %
# 7        Obesity      Diabetes  0.379310        37.93 %

# %%
bar_chart(
    grouped_chd_bmi,
    "BMICategory",
    "per",
    txt = "annotation_per",
    labls = {'BMICategory': 'BMI Category', 'diabetes': 'Diabetes', 'per': 'CHD Risk'},
    hover={"annotation_per":False},
    colors =['#bdbdbd','#008294'] ,
    height=600,
    width=900,
    ttle="10-Year CHD Risk Percentage: BMI Category vs. Diabetes",
    xtitle="BMI Category" ,
    ytitle="10-Year CHD Risk %" ,
    colour='diabetes', 
    bg=0.3, 
    bgg=0.1,
    yscale = False,
    yscale_percentage=True
)

# %% [markdown]
# ## Answer5
#
# #### **From above visualisations we can see that**
#
#
# **1. The diabetic patients consistently exhibit a higher 10-year CHD risk compared to those non-diabetic patients within the same BMI group.**
#
# **2. the highest CHD risk in diabetic underweight patients (approximately 50%), followed by overweight (38.3%) and obese patients (38%).**
#
# **3. Diabetic patients have a consistently higher 10-year CHD risk compared to non-diabetic patients within the same BMI group.**

# %% [markdown]
# <a id='q6'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 6
#
# > #### 6. Is there a correlation between 10-year CHD risk and any of the following fratures?
#
# **A. Age**
#
# **B. Smoking patterns**
#
# **C.  Blood Pressure**
#
# **D.  BMI**

# %%
# correlations with heatmap

fig, ax = plt.subplots(figsize=(20,5))
corr_matrix = df_clean.corr(numeric_only=True)
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr_matrix, annot=True, mask=mask);

plt.title( 'Numaric Variables Correlations Heatmap', fontsize=20, fontweight='bold', fontfamily='serif', pad=15);

# %%
dic = {"correlation":[], "p_value" :[]}
columns = ["age", "cigsPerDay", "sysBP", "diaBP", "BMI"]
for i in columns:
    r_pb, p_value = stats.pointbiserialr(df_clean[i], df_clean["TenYearCHD"])
    dic["correlation"].append(round(r_pb, 2))
    dic["p_value"].append(round(p_value, 4))
    
corr_df = pd.DataFrame(dic)
corr_df.index = ["Age", "Cigars per day", "Systolic BP","Diastolic BP", "BMI"]
corr_df = corr_df.reset_index()
corr_df = corr_df.rename(columns={"index": "Features"})
corr_df
# Out:
#          Features  correlation  p_value
# 0             Age         0.23   0.0000
# 1  Cigars per day         0.05   0.0007
# 2     Systolic BP         0.22   0.0000
# 3    Diastolic BP         0.15   0.0000
# 4             BMI         0.08   0.0000

# %%
fig = px.bar(corr_df, x='Features', y='correlation',text='correlation',
             labels={'TenYearCHD': '10-year CHD risk', 'count': 'Count', 'bmi_group_per': 'BMI Group'}, color='Features',
             hover_data={'correlation':True,'p_value':True},
             color_discrete_sequence = ['#008294', '#4D4D4D', '#bdbdbd', '#FF7F0E', '#f3ca20 ']

            # color_discrete_sequence=['#008294','#4D4D4D','#bdbdbd','#5A5A8B','#FF7F0E','#008294','#4D4D4D','#bdbdbd','#5A5A8B','#FF7F0E','#008080',]
             ,height=600, width=1100)



fig.update_traces(textfont_size=15, textposition='outside')



fig.update_layout(
    legend_title_text=None,
    #background 
    plot_bgcolor="white", bargap=0.5, title={'text': 'Correlation between 10-year CHD and (Age, Cigars per day, Blood pressure and BMI) ', 'y': 0.95, 'x': 0.5, 'xanchor': 'center', 'yanchor': 'top'}, #title center and size
    title_font_size=20,  # Title font size
    xaxis=dict(
        title='X Axis Title',  # Example X axis title
        titlefont_size=14,  # Size of the X axis title font
        tickfont_size=12,   # Size of the X axis tick labels font
        showline=True,  # Show x-axis line
        showgrid=False, # showgrid
        gridcolor="lightgray",),
    yaxis=dict(
        title='Y Axis Title',  # Example Y axis title
        titlefont_size=14,  # Size of the Y axis title font
        tickfont_size=12,   # Size of the Y axis tick labels font
        range=[-1, 1], 
     
        showgrid=True, # showgrid   
    ),
    legend=dict(
        font_size=12,  # Size of the legend font
    ),

    # font
    font=dict(
        family='Arial', size=14  # Overall font size
    )
)

fig.update_xaxes(title_text="Features", # Y axisTitle
                 showline=True,  # Show y-axis line
                linecolor='gray',
                titlefont_size=14,  # Set the title font size (optional)
                titlefont_color="black",  # Set the title font color (optional)
                 )

fig.update_yaxes(title_text="Correlation", # Y axisTitle
                 range=[-1, 1],
                 showline=True,  # Show y-axis line
                 linecolor='gray',  # Color of the y-axis line
                 titlefont_size=14,  # Set the title font size (optional)
                titlefont_color="black",  # Set the title font color (optional)         )
                )
fig.add_hline(y=0.7, line=dict(color="red", width=1, dash="dash"))
fig.add_annotation(y=0.7, text="Strong positive correlation line", showarrow=False,
                       xanchor='center', yanchor='bottom', font=dict(color="red"))

fig.add_hline(y=-0.7, line=dict(color="blue", width=1, dash="dash"))
fig.add_annotation(y=-0.7, text="Strong negative correlation line", showarrow=False,
                       xanchor='center', yanchor='bottom', font=dict(color="blue"))
# Show the plot
fig.show()

# %% [markdown]
# ## Answer 6
#
# #### **From above visualisation we can see that**
#
#
# **The Factors: age, cigars smoked daily, blood pressure, and BMI, do not individually have a statistically significant correlation with 10-year CHD risk.**

# %% [markdown]
# <a id='q7'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 7
#
# > #### 7. What is the average number of cigarettes smoked per day for patients with and without 10-year CHD risk?

# %%
avg_sig = df_clean.groupby(['TenYearCHD']).cigsPerDay.mean().reset_index(name='cigsPerDay_AVG')
avg_sig["cigsPerDay_AVG"] = round(avg_sig["cigsPerDay_AVG"], 0)
avg_sig["TenYearCHD"] = avg_sig["TenYearCHD"].apply(lambda x : "CHD" if x == 1 else "No CHD")
avg_sig
# Out:
#   TenYearCHD  cigsPerDay_AVG
# 0     No CHD             9.0
# 1        CHD            11.0

# %%
bar_chart(
    avg_sig,
    "TenYearCHD",
    "cigsPerDay_AVG",
    txt = "cigsPerDay_AVG",
    labls ={'TenYearCHD': '10-year CHD risk', 'cigsPerDay_AVG': 'Average Smoked Sigares Per Day'}, 
    colors =['#4D4D4D','#008294','#bdbdbd','#008080','#5A5A8B'],
    height=600,
    width=900,
    ttle="Cigarette Consumption Average by 10-Year CHD Risk",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Cigarette Consumption AVG" ,
    colour='TenYearCHD', 
    bg=0.3, 
    bgg=0.1,
    leg = "10-years CHD risk"
)

# %% [markdown]
# ### Answer 7
#
#
# #### **From above visualisation we can see that**
#
# **There's a little difference in The average number of cigarettes smoked in between both groups**

# %% [markdown]
# <a id='q8'></a>
#
# <h4 style= "float: right"> <a href="#TOC" ><u>Go to Table of content</u></a> </h4>
#
# ### Research Question 8
#
# > #### 8.  How does the distribution of age, cholesterol level, heart rate, blood glucose, BMI, and mean arterial pressure (MAP) vary among patients with 10-year CHD compared to patients without CHD?

# %%
df_clean_box = df_clean.copy()
df_clean_box["TenYearCHD"] = df_clean_box["TenYearCHD"].apply(lambda x : "CHD" if x == 1 else "No CHD")
df_clean_box["currentSmoker"] = df_clean_box["currentSmoker"].apply(lambda x : "Smoker" if x == 1 else "Non-Smoker")
df_clean_box["prevalentStroke"] = df_clean_box["prevalentStroke"].apply(lambda x : "Had Stroke" if x == 1 else "No Stroke")
df_clean_box["diabetes"] = df_clean_box["diabetes"].apply(lambda x : "Has Diabetes" if x == 1 else "No Diabetes")

# %%
sns.set_style("whitegrid")
fig,ax = plt.subplots(3,2,figsize=(16,8))

sns.kdeplot(df_clean_box, x="age", 
                 fill=False,hue="TenYearCHD",
                linewidth=1.5, alpha=0.8,
                zorder=3,
            ax=ax[0,0]
               )
ax[0,0].set_title("Age Distribution", fontsize=14, color="k")
ax[0,0].set_xlabel("Age", fontsize=12, color="k")
ax[0,0].set_ylabel("Density", fontsize=12, color="k")


sns.kdeplot(df_clean_box, x="totChol", 
                 fill=False,hue="TenYearCHD",
                linewidth=1.5, alpha=0.8,
                zorder=3,
            ax=ax[0,1]
               )
ax[0,1].set_title("Cholesterol Level Distribution", fontsize=14, color="k")
ax[0,1].set_xlabel("Cholesterol Level", fontsize=12, color="k")
ax[0,1].set_ylabel("Density", fontsize=12, color="k")


sns.kdeplot(df_clean_box, x="glucose", 
                 fill=False,hue="TenYearCHD",
                linewidth=1.5, alpha=0.8,
                zorder=3,
            ax=ax[1,1]
               )
ax[1,1].set_title("Glucose Level Distribution", fontsize=14, color="k")
ax[1,1].set_xlabel("Glucose Level", fontsize=12, color="k")
ax[1,1].set_ylabel("Density", fontsize=12, color="k")


sns.kdeplot(df_clean_box, x="heartRate", 
                 fill=False,hue="TenYearCHD",
                linewidth=1.5, alpha=0.8,
                zorder=3,
            ax=ax[1,0]
               )
ax[1,0].set_title("Heart Rate Distribution", fontsize=12, color="k")
ax[1,0].set_xlabel("Heart Rate", fontsize=12, color="k")
ax[1,0].set_ylabel("Density", fontsize=12, color="k")


sns.kdeplot(df_clean_box, x="BMI", 
                 fill=False,hue="TenYearCHD",
                linewidth=1.5, alpha=0.8,
                zorder=3,
            ax=ax[2,0]
               )
ax[2,0].set_title("BMI Distribution", fontsize=14, color="k")
ax[2,0].set_xlabel("BMI", fontsize=12, color="k")
ax[2,0].set_ylabel("Density", fontsize=12, color="k")




sns.kdeplot(df_clean_box, x="MAP", 
                 fill=False,hue="TenYearCHD",
                linewidth=1.5, alpha=0.8,
                zorder=3,
            ax=ax[2,1]
               )
ax[2,1].set_title("MAP Distribution", fontsize=14, color="k")
ax[2,1].set_xlabel("MAP ", fontsize=12, color="k")
ax[2,1].set_ylabel("Density", fontsize=12, color="k")

plt.subplots_adjust(hspace = 0.8, wspace=0.2);

# %%
bar_chart(
    df_clean_box,
    "TenYearCHD",
    "totChol",
    colors =['#4D4D4D','#008294','#bdbdbd','#008080','#5A5A8B'],
    height=600,
    width=900,
    ttle="Distribution of Cholesterol Levels impact for 10-Year CHD Risk, Varies by Prevalent Stroke ",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Cholesterol leveL" ,
    colour='prevalentStroke', 
    bg=0.6, 
    bgg=0.8,
    leg="Prevalent Stroke",
    box=True
)

# %%
bar_chart(
    df_clean_box,
    "TenYearCHD",
    "totChol",
    colors =['#4D4D4D','#008294','#bdbdbd','#008080','#5A5A8B'],
    height=600,
    width=900,
    ttle="Distribution of Cholesterol Levels impact for 10-Year CHD Risk, Varies by Diabetes ",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Cholesterol leveL" ,
    colour='diabetes', 
    bg=0.6, 
    bgg=0.1,
    box=True
)

# %%
bar_chart(
    df_clean_box,
    "TenYearCHD",
    "totChol",
    colors =['#4D4D4D','#008294','#bdbdbd','#5A5A8B', "orange"],
    height=600,
    width=900,
    ttle="Distribution of Cholesterol Levels impact for 10-Year CHD Risk, Varies by Age Group ",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Cholesterol leveL" ,
    colour='ageGroup', 
    bg=0.6, 
    bgg=0.1,
    leg="Age Group",
    box=True
)

# %%
bar_chart(
    df_clean_box,
    "TenYearCHD",
    "heartRate",
    colors =['#4D4D4D','#008294','#bdbdbd','#008080','#5A5A8B'],
    height=600,
    width=900,
    ttle="Distribution of Heart Rate impact for 10-Year CHD Risk, Varies by Prevalent Stroke ",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Heart Rate" ,
    colour='prevalentStroke', 
    bg=0.6, 
    bgg=0.1,
    leg="Prevalent Stroke",
    box=True
)

# %%
bar_chart(
    df_clean_box,
    "TenYearCHD",
    "heartRate",
    colors =['#4D4D4D','#008294','#bdbdbd','#008080','#5A5A8B'],
    height=600,
    width=900,
    ttle="Distribution of Heart Rate impact for 10-Year CHD Risk, Varies by Diabetes ",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Heart Rate" ,
    colour='diabetes', 
    bg=0.6, 
    bgg=0.1,
    box=True
)

# %%
bar_chart(
    df_clean_box,
    "TenYearCHD",
    "heartRate",
    colors =['#4D4D4D','#008294','#bdbdbd','#5A5A8B', "orange"],
    height=600,
    width=900,
    ttle="Distribution of Heart Rate impact for 10-Year CHD Risk, Varies by Age Group ",
    xtitle="Ten-Year CHD Risk" ,
    ytitle="Heart Rate" ,
    colour='ageGroup', 
    bg=0.6, 
    bgg=0.1,
    leg="Age Group",
    box=True
)

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# **1. :**
#
#
#  * .

# %% [markdown]
# <a id='limitation'></a>
# ## Limitations
#
#
# ###
#
# **.**
